# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/dc_bikes.csv", parse_dates=["datetime"])
df
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 0     2011-01-01 00:00:00       1        0           0        1   9.84
# 1     2011-01-01 01:00:00       1        0           0        1   9.02
# 2     2011-01-01 02:00:00       1        0           0        1   9.02
# 3     2011-01-01 03:00:00       1        0           0        1   9.84
# 4     2011-01-01 04:00:00       1        0           0        1   9.84
# ...                   ...     ...      ...         ...      ...    ...
# 17374 2012-12-31 19:00:00       1        0           1        2  10.66
# 17375 2012-12-31 20:00:00       1        0           1        2  10.66
# 17376 2012-12-31 21:00:00       1        0           1        1  10.66
# 17377 2012-12-31 22:00:00       1        0           1        1  10.66
# 17378 2012-12-31 23:00:00       1        0           1        1  10.66
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %%
df.head(10)
# Out:
#              datetime  season  holiday  workingday  weather   temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1   9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1   9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1   9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1   9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1   9.84  14.395
# 5 2011-01-01 05:00:00       1        0           0        2   9.84  12.880
# 6 2011-01-01 06:00:00       1        0           0        1   9.02  13.635
# 7 2011-01-01 07:00:00       1        0           0        1   8.20  12.880
# 8 2011-01-01 08:00:00       1        0           0        1   9.84  14.395
# 9 2011-01-01 09:00:00       1        0           0        1  13.12  17.425
#
#    humidity  windspeed  casual  registered  count
# 0        81     0.0000     3.0        13.0     16
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    17379 non-null  datetime64[ns]
#  1   season      17379 non-null  int64
#  2   holiday     17379 non-null  int64
#  3   workingday  17379 non-null  int64
#  4   weather     17379 non-null  int64
#  5   temp        17379 non-null  float64
#  6   atemp       17379 non-null  float64
#  7   humidity    17379 non-null  int64
#  8   windspeed   17379 non-null  float64
#  9   casual      10886 non-null  float64
#  10  registered  10886 non-null  float64
#  11  count       17379 non-null  int64
# dtypes: datetime64[ns](1), float64(5), int64(6)
# memory usage: 1.6 MB

# %%
df["day"] = df["datetime"].dt.day

# %%
df["hour"] = df["datetime"].dt.hour

# %%
df["month"] = df["datetime"].dt.month

# %%
df.head(10)
# Out:
#              datetime  season  holiday  workingday  weather   temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1   9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1   9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1   9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1   9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1   9.84  14.395
# 5 2011-01-01 05:00:00       1        0           0        2   9.84  12.880
# 6 2011-01-01 06:00:00       1        0           0        1   9.02  13.635
# 7 2011-01-01 07:00:00       1        0           0        1   8.20  12.880
# 8 2011-01-01 08:00:00       1        0           0        1   9.84  14.395
# 9 2011-01-01 09:00:00       1        0           0        1  13.12  17.425
#
#    humidity  windspeed  casual  registered  count  day  hour  month
# 0        81     0.0000     3.0        13.0     16    1     0      1
# ...

# %%
df.groupby(by="month")['datetime'].count()
# Out:
# month
# 1     1429
# 2     1341
# 3     1473
# 4     1437
# 5     1488
# 6     1440
# 7     1488
# 8     1475
# 9     1437
# 10    1451
# 11    1437
# 12    1483
# Name: datetime, dtype: int64

# %%
df.groupby(by='month')['datetime'].count().plot.bar();

# %%
df.groupby(by="day")['datetime'].count()
# Out:
# day
# 1     575
# 2     573
# 3     573
# 4     574
# 5     575
# 6     572
# 7     574
# 8     574
# 9     575
# 10    572
# 11    568
# 12    573
# 13    574
# 14    574
# 15    574
# 16    574
# 17    575
# 18    563
# 19    574
# 20    574
# 21    574
# 22    569
# 23    573
# 24    573
# 25    572
# 26    567
# 27    552
# 28    563
# 29    526
# 30    514
# 31    336
# Name: datetime, dtype: int64

# %%
df.groupby(by="day")['datetime'].count().plot.bar();

# %%
df.groupby(by="hour")['datetime'].count()
# Out:
# hour
# 0     726
# 1     724
# 2     715
# 3     697
# 4     697
# 5     717
# 6     725
# 7     727
# 8     727
# 9     727
# 10    727
# 11    727
# 12    728
# 13    729
# 14    729
# 15    729
# 16    730
# 17    730
# 18    728
# 19    728
# 20    728
# 21    728
# 22    728
# 23    728
# Name: datetime, dtype: int64

# %%
df.groupby(by="hour")['datetime'].count().plot();

# %%
df['hour'].min(), df['hour'].max()
# Out:
# (0, 23)

# %%
bin_labels = ["night", "morning", "afternoon", "evening", "night"]

# %%
bin_boundaries = [-1, 7, 12, 18, 22, 24]

# %%
df['part_of_day'] = pd.cut(df['hour'], bins=bin_boundaries, labels=bin_labels, ordered=False)

# %%
df.to_csv("../data/dc_bikes_new.csv")

# %%
df.head(10)
# Out:
#              datetime  season  holiday  workingday  weather   temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1   9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1   9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1   9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1   9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1   9.84  14.395
# 5 2011-01-01 05:00:00       1        0           0        2   9.84  12.880
# 6 2011-01-01 06:00:00       1        0           0        1   9.02  13.635
# 7 2011-01-01 07:00:00       1        0           0        1   8.20  12.880
# 8 2011-01-01 08:00:00       1        0           0        1   9.84  14.395
# 9 2011-01-01 09:00:00       1        0           0        1  13.12  17.425
#
#    humidity  windspeed  casual  registered  count  day  hour  month  \
# 0        81     0.0000     3.0        13.0     16    1     0      1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   datetime     17379 non-null  datetime64[ns]
#  1   season       17379 non-null  int64
#  2   holiday      17379 non-null  int64
#  3   workingday   17379 non-null  int64
#  4   weather      17379 non-null  int64
#  5   temp         17379 non-null  float64
#  6   atemp        17379 non-null  float64
#  7   humidity     17379 non-null  int64
#  8   windspeed    17379 non-null  float64
#  9   casual       10886 non-null  float64
#  10  registered   10886 non-null  float64
#  11  count        17379 non-null  int64
#  12  day          17379 non-null  int64
#  13  hour         17379 non-null  int64
#  14  month        17379 non-null  int64
#  15  part_of_day  17379 non-null  category
# dtypes: category(1), datetime64[ns](1), float64(5), int64(9)
# memory usage: 2.0 MB

# %%
df.groupby(by="part_of_day")["count"].mean()
# Out:
# part_of_day
# afternoon    322.162743
# evening      210.321429
# morning      240.588834
# night         59.046004
# Name: count, dtype: float64

# %%
df_2011 = pd.read_csv('../data/dc_bikes_new.csv', index_col=0, parse_dates=['datetime'])

# %%
df_2011 = df_2011.set_index("datetime")
df_2011
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1   9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1   9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1   9.84  14.395
# ...                     ...      ...         ...      ...    ...     ...
# 2012-12-31 19:00:00       1        0           1        2  10.66  12.880
# 2012-12-31 20:00:00       1        0           1        2  10.66  12.880
# 2012-12-31 21:00:00       1        0           1        1  10.66  12.880
# 2012-12-31 22:00:00       1        0           1        1  10.66  13.635
# 2012-12-31 23:00:00       1        0           1        1  10.66  13.635
#
#                      humidity  windspeed  casual  registered  count  day  \
# ...

# %%
df_2011.loc["2011-01"]
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1   9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1   9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1   9.84  14.395
# ...                     ...      ...         ...      ...    ...     ...
# 2011-01-31 19:00:00       1        0           1        1  12.30  15.910
# 2011-01-31 20:00:00       1        0           1        3   6.56   8.335
# 2011-01-31 21:00:00       1        0           1        3   6.56   9.850
# 2011-01-31 22:00:00       1        0           1        2   6.56   9.090
# 2011-01-31 23:00:00       1        0           1        2   6.56   9.850
#
#                      humidity  windspeed  casual  registered  count  day  \
# ...

# %%
df_monthly = pd.read_csv('../data/dc_bikes_new.csv', index_col=0, parse_dates=["datetime"])
df_monthly
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 0     2011-01-01 00:00:00       1        0           0        1   9.84
# 1     2011-01-01 01:00:00       1        0           0        1   9.02
# 2     2011-01-01 02:00:00       1        0           0        1   9.02
# 3     2011-01-01 03:00:00       1        0           0        1   9.84
# 4     2011-01-01 04:00:00       1        0           0        1   9.84
# ...                   ...     ...      ...         ...      ...    ...
# 17374 2012-12-31 19:00:00       1        0           1        2  10.66
# 17375 2012-12-31 20:00:00       1        0           1        2  10.66
# 17376 2012-12-31 21:00:00       1        0           1        1  10.66
# 17377 2012-12-31 22:00:00       1        0           1        1  10.66
# 17378 2012-12-31 23:00:00       1        0           1        1  10.66
#
#         atemp  humidity  windspeed  casual  registered  count  day  hour  \
# ...

# %%
df_monthly["rolling"] = df_monthly["count"].rolling(window=6).mean()

# %%
df_monthly
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 0     2011-01-01 00:00:00       1        0           0        1   9.84
# 1     2011-01-01 01:00:00       1        0           0        1   9.02
# 2     2011-01-01 02:00:00       1        0           0        1   9.02
# 3     2011-01-01 03:00:00       1        0           0        1   9.84
# 4     2011-01-01 04:00:00       1        0           0        1   9.84
# ...                   ...     ...      ...         ...      ...    ...
# 17374 2012-12-31 19:00:00       1        0           1        2  10.66
# 17375 2012-12-31 20:00:00       1        0           1        2  10.66
# 17376 2012-12-31 21:00:00       1        0           1        1  10.66
# 17377 2012-12-31 22:00:00       1        0           1        1  10.66
# 17378 2012-12-31 23:00:00       1        0           1        1  10.66
#
#         atemp  humidity  windspeed  casual  registered  count  day  hour  \
# ...

# %%
plt.plot(df_monthly.index, df_monthly["count"])
plt.plot(df_monthly.index, df_monthly["rolling"])
plt.xticks(rotation=38)
plt.title("Data with rolling average/monthly")
plt.show();

# %%
df["week_day"] =  df["datetime"].dt.day_name()

# %%
df.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  day  hour  month  \
# 0        81        0.0     3.0        13.0     16    1     0      1
# 1        80        0.0     8.0        32.0     40    1     1      1
# 2        80        0.0     5.0        27.0     32    1     2      1
# 3        75        0.0     3.0        10.0     13    1     3      1
# 4        75        0.0     0.0         1.0      1    1     4      1
#
#   part_of_day  week_day
# 0       night  Saturday
# 1       night  Saturday
# 2       night  Saturday
# ...

# %%
df_week_days_cas = df.pivot_table(
    values=["casual", "registered", "count"],
    columns=["week_day"],
    aggfunc="mean",
    sort=False
)
df_week_days_cas = df_week_days_cas.transpose()

# %%
df_week_days_cas
# Out:
#               casual  registered       count
# week_day
# Saturday   63.625000  133.040404  194.396497
# Sunday     57.051298  123.788474  182.842126
# Monday     29.843972  160.546744  175.096410
# Tuesday    22.979207  166.744639  180.951080
# Wednesday  22.521599  165.889749  187.644040
# Thursday   24.007083  173.289118  198.999595
# Friday     31.001962  166.842381  200.249698

# %%
plt.figure(figsize=(10,6))
sns.set_style("darkgrid")
plt.title("Casual, Registred, Count")
sns.lineplot(data=df_week_days_cas, y="casual", x=df_week_days_cas.index, label="Casual")
sns.lineplot(data=df_week_days_cas, y="registered", x=df_week_days_cas.index, label="Registred")
sns.lineplot(data=df_week_days_cas, y="count", x=df_week_days_cas.index, label="Count");

# %%
df_pivot_hour_day = df.pivot_table(
    values="count",
    index=["hour"],
    columns=["week_day"],
    aggfunc="sum",
    sort=False
)
df_pivot_hour_day

# %%
plt.figure(figsize=(10,6))
sns.set_style("darkgrid")
plt.title("Hour per day")
sns.lineplot(data=df_pivot_hour_day, y="Saturday", x="hour", label="Saturday")
sns.lineplot(data=df_pivot_hour_day, y="Sunday", x="hour", label="Sunady")
sns.lineplot(data=df_pivot_hour_day, y="Monday", x="hour", label="Monday")
sns.lineplot(data=df_pivot_hour_day, y="Tuesday", x="hour", label="Tuesday")
sns.lineplot(data=df_pivot_hour_day, y="Wednesday", x="hour", label="Wednesday")
sns.lineplot(data=df_pivot_hour_day, y="Thursday", x="hour", label="Thursday")
sns.lineplot(data=df_pivot_hour_day, y="Friday", x="hour", label="Friday")
plt.xticks(rotation=45);

# %%
df_2011 = pd.read_csv('../data/dc_bikes_new.csv', index_col=0, parse_dates=['datetime'])
df_2011 = df_2011.set_index("datetime")
df_2011
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1   9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1   9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1   9.84  14.395
# ...                     ...      ...         ...      ...    ...     ...
# 2012-12-31 19:00:00       1        0           1        2  10.66  12.880
# 2012-12-31 20:00:00       1        0           1        2  10.66  12.880
# 2012-12-31 21:00:00       1        0           1        1  10.66  12.880
# 2012-12-31 22:00:00       1        0           1        1  10.66  13.635
# 2012-12-31 23:00:00       1        0           1        1  10.66  13.635
#
#                      humidity  windspeed  casual  registered  count  day  \
# ...

# %%
df_2011 = df_2011.loc["2011-05"]

# %%
df_may_11 = df_2011.groupby("day")["count"].sum().to_frame().reset_index()
df_may_11
# Out:
#     day  count
# 0     1   3351
# 1     2   4401
# 2     3   4451
# 3     4   2633
# 4     5   4433
# 5     6   4608
# 6     7   4714
# 7     8   4333
# 8     9   4362
# 9    10   4803
# 10   11   4182
# 11   12   4864
# 12   13   4105
# 13   14   3409
# 14   15   4553
# 15   16   3958
# 16   17   4123
# 17   18   3855
# 18   19   4575
# 19   20   6699
# 20   21   7787
# 21   22   6161
# 22   23   4390
# 23   24   4799
# 24   25   5903
# 25   26   6252
# 26   27   6725
# 27   28   6743
# 28   29   5341
# 29   30   5209
# 30   31   4808

# %%
df_may_11
# Out:
#     day  count
# 0     1   3351
# 1     2   4401
# 2     3   4451
# 3     4   2633
# 4     5   4433
# 5     6   4608
# 6     7   4714
# 7     8   4333
# 8     9   4362
# 9    10   4803
# 10   11   4182
# 11   12   4864
# 12   13   4105
# 13   14   3409
# 14   15   4553
# 15   16   3958
# 16   17   4123
# 17   18   3855
# 18   19   4575
# 19   20   6699
# 20   21   7787
# 21   22   6161
# 22   23   4390
# 23   24   4799
# 24   25   5903
# 25   26   6252
# 26   27   6725
# 27   28   6743
# 28   29   5341
# 29   30   5209
# 30   31   4808

# %%
df_2012 = pd.read_csv('../data/dc_bikes_new.csv', index_col=0, parse_dates=['datetime'])
df_2012 = df_2012.set_index("datetime")
df_2012
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2011-01-01 00:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 01:00:00       1        0           0        1   9.02  13.635
# 2011-01-01 02:00:00       1        0           0        1   9.02  13.635
# 2011-01-01 03:00:00       1        0           0        1   9.84  14.395
# 2011-01-01 04:00:00       1        0           0        1   9.84  14.395
# ...                     ...      ...         ...      ...    ...     ...
# 2012-12-31 19:00:00       1        0           1        2  10.66  12.880
# 2012-12-31 20:00:00       1        0           1        2  10.66  12.880
# 2012-12-31 21:00:00       1        0           1        1  10.66  12.880
# 2012-12-31 22:00:00       1        0           1        1  10.66  13.635
# 2012-12-31 23:00:00       1        0           1        1  10.66  13.635
#
#                      humidity  windspeed  casual  registered  count  day  \
# ...

# %%
df_2012=df_2012.loc["2012-05"]

# %%
df_may_12 = df_2012.groupby("day")["count"].sum().to_frame().reset_index()
df_may_12
# Out:
#     day  count
# 0     1   5740
# 1     2   6169
# 2     3   6421
# 3     4   6296
# 4     5   6883
# 5     6   6359
# 6     7   6273
# 7     8   5728
# 8     9   4717
# 9    10   6572
# 10   11   7030
# 11   12   7429
# 12   13   6118
# 13   14   2843
# 14   15   5115
# 15   16   7424
# 16   17   7384
# 17   18   7639
# 18   19   8294
# 19   20   6838
# 20   21   3948
# 21   22   4893
# 22   23   4859
# 23   24   6172
# 24   25   6674
# 25   26   6614
# 26   27   6105
# 27   28   6264
# 28   29   4761
# 29   30   4799
# 30   31   5556

# %%
plt.figure(figsize=(10,6))
sns.set_style("darkgrid")
plt.title("Count per day 'May 2011, May 2012'")
sns.lineplot(x="day", y="count", data=df_may_12)
sns.lineplot(x="day", y="count", data=df_may_11)
plt.text(0, df_may_12["count"].mean()+10, "Mean of forecast count", color='green')
plt.axhline(df_may_12["count"].mean(), color='green', ls='--')
plt.legend(["forecasts", "actual"]);

# %%
import statsmodels.tools.eval_measures as sm

# %%
df_rmse_count = sm.rmse(df_may_11["count"], df_may_12["count"])
df_rmse_count
# Out:
# 2078.1589634624575

# %%
df_may_12_mean = df_2012.groupby("day")["count"].mean().to_frame().reset_index()
df_may_12_mean
# Out:
#     day       count
# 0     1  239.166667
# 1     2  257.041667
# 2     3  267.541667
# 3     4  262.333333
# 4     5  286.791667
# 5     6  264.958333
# 6     7  261.375000
# 7     8  238.666667
# 8     9  196.541667
# 9    10  273.833333
# 10   11  292.916667
# 11   12  309.541667
# 12   13  254.916667
# 13   14  118.458333
# 14   15  213.125000
# 15   16  309.333333
# 16   17  307.666667
# 17   18  318.291667
# 18   19  345.583333
# 19   20  284.916667
# 20   21  164.500000
# 21   22  203.875000
# 22   23  202.458333
# 23   24  257.166667
# 24   25  278.083333
# 25   26  275.583333
# 26   27  254.375000
# 27   28  261.000000
# 28   29  198.375000
# 29   30  199.958333
# 30   31  231.500000

# %%
df_may_11_mean = df_2011.groupby("day")["count"].mean().to_frame().reset_index()
df_may_11_mean
# Out:
#     day       count
# 0     1  139.625000
# 1     2  183.375000
# 2     3  185.458333
# 3     4  109.708333
# 4     5  184.708333
# 5     6  192.000000
# 6     7  196.416667
# 7     8  180.541667
# 8     9  181.750000
# 9    10  200.125000
# 10   11  174.250000
# 11   12  202.666667
# 12   13  171.041667
# 13   14  142.041667
# 14   15  189.708333
# 15   16  164.916667
# 16   17  171.791667
# 17   18  160.625000
# 18   19  190.625000
# 19   20  279.125000
# 20   21  324.458333
# 21   22  256.708333
# 22   23  182.916667
# 23   24  199.958333
# 24   25  245.958333
# 25   26  260.500000
# 26   27  280.208333
# 27   28  280.958333
# 28   29  222.541667
# 29   30  217.041667
# 30   31  200.333333

# %%
plt.figure(figsize=(10,6))
sns.set_style("darkgrid")
plt.title("Mean per day 'May 2011, May 2012'")
sns.scatterplot(x="day", y="count", data=df_may_12_mean)
sns.scatterplot(x="day", y="count", data=df_may_11_mean)
plt.text(0, df_may_11_mean["count"].mean()+1, "Mean of forecast count", color='green')
plt.axhline(df_may_11_mean["count"].mean(), color='green', ls='--')
plt.legend(["forecasts", "actual"]);

# %%
df_rmse_mean = sm.rmse(df_may_11_mean["count"], df_may_12_mean["count"])
df_rmse_mean
# Out:
# 86.58995681093573

# %%
df["week_day"] =  df["datetime"].dt.day_name()

# %%
#df.to_csv("../data/dc_bikes_new_days.csv")
